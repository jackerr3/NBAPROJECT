# %%
# imports and setup 
from bs4 import BeautifulSoup
# you can use either of these libraries to get html from a website
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import pandas as pd
import scipy as sc
import numpy as np
import time
import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6) 
from string import ascii_lowercase

# %%
career_pergame = pd.read_csv('career_pergame.csv',index_col=0)

# %%
career_per36 = pd.read_csv('career_per36.csv',index_col=0)

# %%
career_per100 = pd.read_csv('career_per100.csv',index_col=0)

# %%
career_advanced = pd.read_csv('career_advanced.csv',index_col=0)

# %%
career_pergame = career_pergame.set_index('Name')

# %%
career_per36 = career_per36.set_index('Name')

# %%
career_per100 = career_per100.set_index('Name')

# %%
career_advanced = career_advanced.set_index('Name')

# %%
dfs = [career_pergame,career_per36,career_per100,career_advanced]
career = dfs[0].join(dfs[1:])

# %%
cols = [c for c in career.columns if c.lower()[:5] != 'blank']

# %%
career = career[cols]

# %%
cols = [c for c in career.columns if c.lower()[len(c)-2:] != '_y']

# %%
career = career[cols]

# %%
career = career.loc[:,~career.columns.duplicated()]

# %%
career = career.drop('Year_x',axis=1)

# %%
career = career.drop('League_x',axis=1)

# %%
#Only want to run once for backup purposes
#career.to_csv('career.csv')

# %%
career['Percent_Games_Started'] = career['Games Started_x']/career['Games Played_x']

# %%
#rookie datasets
rookie_pergame = pd.read_csv('per_game.csv', index_col = 0)

# %%
rookie_per36 = pd.read_csv('per_36.csv', index_col = 0)

# %%
rookie_per100 = pd.read_csv('per_100.csv', index_col = 0)

# %%
rookie_advanced = pd.read_csv('rookie_advanced.csv', index_col = 0)

# %%
rookie_pergame = rookie_pergame.set_index('Name')

# %%
rookie_per36 = rookie_per36.set_index('Name')

# %%
rookie_per100 = rookie_per100.set_index('Name')

# %%
rookie_advanced = rookie_advanced.set_index('Name')

# %%
dfs = [rookie_pergame, rookie_per36, rookie_per100, rookie_advanced]
rookie = dfs[0].join(dfs[1:])

# %%
rookie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3731 entries, A.C. Green to Zydrunas Ilgauskas
# Columns: 120 entries, Year_x to VORP
# dtypes: float64(101), int64(3), object(16)
# memory usage: 3.4+ MB

# %%
cols = [c for c in rookie.columns if c.lower()[:5] != 'blank']

# %%
rookie = rookie[cols]

# %%
cols = [c for c in rookie.columns if c.lower()[len(c)-2:] != '_y']

# %%
rookie = rookie[cols]

# %%
rookie = rookie.loc[:,~rookie.columns.duplicated()]

# %%
rookie = rookie.drop(['Year_x','Team_x','League_x'],axis=1)

# %%
for c in rookie.columns:
    if c.lower()[len(c)-2:] == '_x':
        rookie.rename(c = c[:len(c)-2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-4763d296b6eb> in <module>()
#       1 for c in rookie.columns:
#       2     if c.lower()[len(c)-2:] == '_x':
# ----> 3         rookie.rename(c = c[:len(c)-2])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in rename(self, index, columns, **kwargs)
#    2744     def rename(self, index=None, columns=None, **kwargs):
#    2745         return super(DataFrame, self).rename(index=index, columns=columns,
# -> 2746                                              **kwargs)
#    2747
#    2748     @Appender(_shared_docs['fillna'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in rename(self, *args, **kwargs)
#     692         if kwargs:
#     693             raise TypeError('rename() got an unexpected keyword '
# --> 694                             'argument "{0}"'.format(list(kwargs.keys())[0]))
#     695
#     696         if com._count_not_none(*axes.values()) == 0:
#
# TypeError: rename() got an unexpected keyword argument "c"

# %%
rookie
# Out:
#                     Age_x Position_x  Games Played_x  Games Started_x  \
# Name
# A.C. Green           22.0         PF              82              1.0
# A.J. Bramlett        23.0          C               8              0.0
# A.J. English         23.0         SG              70             12.0
# A.J. Guyton          22.0         PG              33              8.0
# A.J. Hammons         24.0          C              22              0.0
# A.J. Price           23.0         PG              56              2.0
# A.J. Wynder          26.0         PG               6              0.0
# Aaron Brooks         23.0         PG              51              0.0
# Aaron Gordon         19.0         PF              47              8.0
# Aaron Gray           23.0          C              61              1.0
# Aaron Harrison       21.0         SG              21              0.0
# Aaron McKie          22.0         SG              45             20.0
# Aaron Miles          22.0         PG              19              0.0
# Aaron Swinson        24.0         SF               9              0.0
# Aaron Williams       22.0         PF               6              0.0
# Abdel Nader          24.0         SF              31              0.0
# Abdul Jeelani        25.0         SF              77              NaN
# Acie Earl            23.0          C              74              8.0
# Acie Law             23.0         PG              56              6.0
# Adam Harrington      22.0         SG              19              0.0
# Adam Keefe           22.0         PF              82              6.0
# Adam Morrison        22.0         PF              78             23.0
# Adonal Foyle         22.0          C              55              1.0
# Adonis Jordan        23.0         PG               6              0.0
# Adonis Thomas        20.0         SF               6              1.0
# Adreian Payne        23.0         PF              32             22.0
# Adrian Branch        23.0         SF              32              0.0
# Adrian Caldwell      23.0         PF              51              0.0
# Adrian Dantley       20.0         SF              77              NaN
# Adrian Griffin       25.0         SG              72             47.0
# ...                   ...        ...             ...              ...
# Winston Crite        22.0         SF              29              0.0
# Winston Garland      23.0         PG              67             62.0
# World B. Free        22.0         SG              71              NaN
# Xavier Henry         19.0         SG              38             16.0
# Xavier McDaniel      22.0         SF              82             80.0
# Xavier Munford       23.0         SG              14              0.0
# Xavier Silas         24.0         SG               2              0.0
# Yakhouba Diawara     24.0         SG              64             19.0
# Yao Ming             22.0          C              82             72.0
# Yaroslav Korolev     18.0         SF              24              0.0
# Yi Jianlian          20.0         PF              66             49.0
# Yinka Dare           22.0          C               1              0.0
# Yogi Ferrell         23.0         PG              46             29.0
# Yuta Tabuse          24.0         PG               4              0.0
# Yvon Joseph          28.0          C               1              0.0
# Zabian Dowdell       26.0         PG              24              0.0
# Zach Collins         20.0          C              46              1.0
# Zach LaVine          19.0         PG              77             40.0
# Zach Randolph        20.0         PF              41              0.0
# Zan Tabak            24.0          C              37              0.0
# Zarko Cabarkapa      22.0         PF              49              4.0
# Zarko Paspalj        23.0         SF              28              1.0
# Zaza Pachulia        19.0          C              59              2.0
# Zeljko Rebraca       29.0          C              74              4.0
# Zelmo Beaty          23.0          C              80              NaN
# Zendon Hamilton      25.0          C               3              0.0
# Zhou Qi              22.0          C              14              0.0
# Zoran Dragic         25.0         SG              16              1.0
# Zoran Planinic       21.0         SG              49              1.0
# Zydrunas Ilgauskas   22.0          C              82             81.0
#
#                     MinPerGame  FGPerGame  FGAPerGame  FG%PerGame  3pPerGame  \
# Name
# A.C. Green                18.8        2.5         4.7       0.539        0.0
# A.J. Bramlett              7.6        0.5         2.6       0.190        0.0
# A.J. English              20.6        3.6         8.2       0.439        0.0
# A.J. Guyton               19.1        2.4         5.8       0.406        0.8
# A.J. Hammons               7.4        0.8         1.9       0.405        0.2
# A.J. Price                15.4        2.6         6.3       0.410        1.1
# A.J. Wynder                6.5        0.5         2.0       0.250        0.0
# Aaron Brooks              11.9        1.8         4.4       0.413        0.7
# Aaron Gordon              17.0        2.0         4.4       0.447        0.3
# Aaron Gray                10.0        1.7         3.3       0.505        0.0
# Aaron Harrison             4.4        0.2         0.9       0.263        0.1
# Aaron McKie               18.4        2.6         5.8       0.444        0.2
# Aaron Miles                6.2        0.3         0.9       0.333        0.0
# Aaron Swinson              5.7        1.1         2.0       0.556        0.0
# Aaron Williams             2.0        0.3         1.3       0.250        0.0
# Abdel Nader                9.1        0.9         2.6       0.354        0.5
# Abdul Jeelani             16.7        3.7         7.3       0.510        0.0
# Acie Earl                 15.5        2.0         5.0       0.406        0.0
# Acie Law                  15.4        1.7         4.2       0.401        0.1
# Adam Harrington            5.8        0.6         1.9       0.297        0.3
# Adam Keefe                18.9        2.3         4.6       0.500        0.0
# Adam Morrison             29.8        4.6        12.1       0.376        1.1
# Adonal Foyle              11.9        1.3         3.1       0.406        0.0
# Adonis Jordan             13.2        1.0         3.8       0.261        0.5
# Adonis Thomas              6.2        1.0         2.3       0.429        0.2
# Adreian Payne             23.1        2.8         6.9       0.414        0.0
# Adrian Branch              6.8        1.5         3.0       0.500        0.0
# Adrian Caldwell            6.5        0.8         1.5       0.553        0.0
# Adrian Dantley            36.6        7.1        13.6       0.520        NaN
# Adrian Griffin            26.8        2.4         5.7       0.424        0.2
# ...                        ...        ...         ...         ...        ...
# Winston Crite              8.9        1.2         2.3       0.500        0.0
# Winston Garland           31.7        5.1        11.6       0.439        0.2
# World B. Free             15.8        3.4         7.5       0.448        NaN
# Xavier Henry              13.9        1.7         4.2       0.406        0.1
# Xavier McDaniel           33.0        7.0        14.3       0.490        0.0
# Xavier Munford            17.4        2.3         5.5       0.416        0.6
# Xavier Silas              19.5        2.0         7.5       0.267        0.5
# Yakhouba Diawara          18.4        1.6         4.6       0.342        0.8
# Yao Ming                  29.0        4.9         9.8       0.498        0.0
# Yaroslav Korolev           5.3        0.4         1.3       0.300        0.1
# Yi Jianlian               25.0        3.3         7.9       0.421        0.1
# Yinka Dare                 3.0        0.0         1.0       0.000        0.0
# Yogi Ferrell              26.0        3.5         8.6       0.406        1.5
# Yuta Tabuse                4.3        0.3         1.5       0.167        0.3
# Yvon Joseph                5.0        0.0         0.0         NaN        0.0
# Zabian Dowdell            12.2        2.1         5.2       0.408        0.1
# Zach Collins              15.2        1.6         4.2       0.387        0.5
# Zach LaVine               24.7        3.7         8.8       0.422        0.7
# Zach Randolph              5.8        1.2         2.6       0.449        0.0
# Zan Tabak                  4.9        0.6         1.4       0.453        0.0
# Zarko Cabarkapa           11.6        1.7         4.0       0.411        0.1
# Zarko Paspalj              6.5        1.0         2.8       0.342        0.0
# Zaza Pachulia             11.3        1.2         3.0       0.389        0.0
# Zeljko Rebraca            15.9        2.6         5.1       0.505        0.0
# Zelmo Beaty               24.0        3.7         8.5       0.439        NaN
# Zendon Hamilton            6.3        0.7         3.0       0.222        0.0
# Zhou Qi                    5.4        0.3         1.7       0.167        0.1
# Zoran Dragic               4.7        0.7         1.9       0.367        0.2
# Zoran Planinic             9.7        1.1         2.6       0.411        0.2
# Zydrunas Ilgauskas        29.0        5.5        10.7       0.518        0.0
#
#                     3PAPerGame  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  \
# Name                            ...
# A.C. Green                 0.1  ...   17.7  14.7  1.4  2.0  3.3  0.103  -0.5
# A.J. Bramlett              0.0  ...   12.5  17.1 -0.2  0.1 -0.2 -0.129 -10.5
# A.J. English               0.4  ...   15.1  21.8 -0.5  0.7  0.2  0.008  -2.5
# A.J. Guyton                2.1  ...   10.7  16.5  0.4 -0.1  0.3  0.020  -1.5
# A.J. Hammons               0.5  ...   16.4  17.6 -0.2  0.2  0.0 -0.001  -7.5
# A.J. Price                 3.1  ...   13.2  22.7  0.4  0.8  1.2  0.065   0.2
# A.J. Wynder                0.2  ...   20.5  21.1 -0.1  0.0  0.0 -0.051  -5.9
# Aaron Brooks               2.1  ...   15.1  21.8  0.6  0.8  1.4  0.112   0.0
# Aaron Gordon               1.0  ...   13.9  15.5  0.3  0.7  1.0  0.060  -2.8
# Aaron Gray                 0.0  ...   18.7  22.0  0.1  0.8  0.8  0.066  -2.4
# Aaron Harrison             0.5  ...   14.1  13.7 -0.2  0.1  0.0 -0.014  -5.6
# Aaron McKie                0.6  ...   11.7  17.0  0.8  1.2  2.0  0.115  -1.2
# Aaron Miles                0.0  ...   35.8  11.6 -0.2  0.1  0.0 -0.015  -7.7
# Aaron Swinson              0.0  ...   19.8  21.4  0.0  0.0  0.0  0.039  -2.9
# Aaron Williams             0.0  ...   10.6  34.8 -0.1  0.0 -0.1 -0.327 -13.7
# Abdel Nader                1.3  ...   18.6  17.1 -0.4  0.4 -0.1 -0.009  -5.3
# Abdul Jeelani              0.1  ...   15.2  24.6  2.3  1.5  3.8  0.141   1.0
# Acie Earl                  0.0  ...   14.0  19.4 -0.7  0.9  0.2  0.008  -5.4
# Acie Law                   0.6  ...   17.8  16.5 -0.5  0.4 -0.1 -0.007  -4.1
# Adam Harrington            0.7  ...    4.9  16.5  0.0  0.1  0.0  0.017  -3.9
# Adam Keefe                 0.0  ...   17.2  15.5  1.9  1.4  3.3  0.102  -1.2
# Adam Morrison              3.3  ...   11.3  22.4 -2.2  0.8 -1.5 -0.030  -3.0
# Adonal Foyle               0.0  ...   20.2  16.4 -1.0  0.9 -0.1 -0.009  -6.9
# Adonis Jordan              1.7  ...   20.7  15.6 -0.1  0.0 -0.1 -0.037  -4.5
# Adonis Thomas              0.8  ...    6.5  18.5  0.0  0.0  0.0  0.001  -4.0
# Adreian Payne              0.3  ...   15.5  17.0 -0.7  0.2 -0.5 -0.033  -4.6
# Adrian Branch              0.1  ...   16.7  26.6  0.4  0.4  0.7  0.158   0.5
# Adrian Caldwell            0.0  ...   26.6  14.8 -0.3  0.7  0.4  0.061  -5.6
# Adrian Dantley             NaN  ...    NaN   NaN  8.2  1.6  9.8  0.167   3.5
# Adrian Griffin             0.8  ...   16.2  13.0  1.8  2.1  3.9  0.098  -0.3
# ...                        ...  ...    ...   ...  ...  ...  ...    ...   ...
# Winston Crite              0.0  ...   24.0  16.4  0.0  0.2  0.1  0.025  -3.2
# Winston Garland            0.6  ...   16.5  19.3  0.8  0.9  1.7  0.039  -0.3
# World B. Free              NaN  ...    NaN   NaN  0.9  0.6  1.5  0.064  -0.4
# Xavier Henry               0.4  ...    6.6  16.8 -0.1  0.3  0.2  0.021  -3.9
# Xavier McDaniel            0.1  ...   15.7  24.5  1.8  3.3  5.1  0.091   0.8
# Xavier Munford             1.6  ...   15.3  18.0 -0.2  0.2  0.1  0.017  -2.9
# Xavier Silas               3.0  ...   15.5  23.3 -0.1  0.0 -0.1 -0.131  -6.8
# Yakhouba Diawara           2.7  ...   10.5  12.8 -0.2  0.8  0.5  0.021  -2.3
# Yao Ming                   0.0  ...   15.2  22.1  5.2  3.5  8.7  0.176   0.2
# Yaroslav Korolev           0.3  ...   14.9  14.7 -0.1  0.1  0.0 -0.013  -4.8
# Yi Jianlian                0.3  ...   13.4  18.4 -0.1  0.9  0.7  0.022  -3.9
# Yinka Dare                 0.0  ...   50.0  29.3 -0.1  0.0  0.0 -0.736 -33.8
# Yogi Ferrell               3.8  ...   13.9  19.6  0.8  1.0  1.8  0.072  -0.1
# Yuta Tabuse                0.3  ...   11.4  22.5  0.0  0.0  0.0  0.129   0.1
# Yvon Joseph                0.0  ...    0.0   7.0  0.0  0.0  0.0  0.309   2.7
# Zabian Dowdell             0.4  ...   18.0  25.0 -0.4  0.2 -0.1 -0.019  -3.5
# Zach Collins               1.5  ...   15.0  15.1 -0.5  0.9  0.4  0.027  -4.4
# Zach LaVine                2.2  ...   20.4  22.0 -0.7  0.0 -0.7 -0.018  -1.7
# Zach Randolph              0.0  ...   11.2  25.7  0.2  0.3  0.5  0.098  -1.7
# Zan Tabak                  0.0  ...   19.9  22.3 -0.1  0.2  0.2  0.043  -5.7
# Zarko Cabarkapa            0.7  ...   19.7  21.7 -0.7  0.3 -0.4 -0.037  -4.8
# Zarko Paspalj              0.0  ...   19.1  25.1 -0.5  0.2 -0.3 -0.072  -7.3
# Zaza Pachulia              0.0  ...   13.7  16.9  0.1  0.2  0.3  0.023  -4.1
# Zeljko Rebraca             0.0  ...   15.7  21.4  1.4  1.9  3.3  0.134  -2.8
# Zelmo Beaty                NaN  ...    NaN   NaN  2.1  3.1  5.2  0.131   NaN
# Zendon Hamilton            0.0  ...   13.8  35.3 -0.1  0.0  0.0 -0.119 -12.8
# Zhou Qi                    1.1  ...   15.0  19.6 -0.3  0.1 -0.2 -0.126 -10.7
# Zoran Dragic               0.9  ...   13.4  22.9 -0.1  0.0 -0.1 -0.042  -2.5
# Zoran Planinic             0.7  ...   18.8  19.0  0.1  0.6  0.7  0.068  -2.8
# Zydrunas Ilgauskas         0.0  ...   12.6  22.4  4.5  4.9  9.4  0.189   0.3
#
#                     DBPM   BPM  VORP
# Name
# A.C. Green           0.8   0.3   0.9
# A.J. Bramlett       -6.3 -16.8  -0.2
# A.J. English        -2.3  -4.8  -1.0
# A.J. Guyton         -4.4  -5.9  -0.6
# A.J. Hammons         2.0  -5.6  -0.1
# A.J. Price          -2.0  -1.8   0.0
# A.J. Wynder         -3.5  -9.4  -0.1
# Aaron Brooks        -1.8  -1.8   0.0
# Aaron Gordon         0.0  -2.8  -0.2
# Aaron Gray           0.4  -2.0   0.0
# Aaron Harrison       0.1  -5.5  -0.1
# Aaron McKie          1.3   0.1   0.4
# Aaron Miles         -0.5  -8.2  -0.2
# Aaron Swinson       -2.9  -5.8   0.0
# Aaron Williams      -4.3 -18.0   0.0
# Abdel Nader         -0.1  -5.4  -0.2
# Abdul Jeelani       -0.8   0.2   0.7
# Acie Earl           -1.7  -7.1  -1.5
# Acie Law            -2.6  -6.7  -1.0
# Adam Harrington     -3.2  -7.1  -0.1
# Adam Keefe           0.1  -1.0   0.4
# Adam Morrison       -2.5  -5.5  -2.0
# Adonal Foyle         1.6  -5.4  -0.6
# Adonis Jordan       -4.2  -8.7  -0.1
# Adonis Thomas       -5.7  -9.7  -0.1
# Adreian Payne       -1.3  -5.9  -0.7
# Adrian Branch       -0.3   0.2   0.1
# Adrian Caldwell      1.3  -4.3  -0.2
# Adrian Dantley      -1.1   2.5   3.2
# Adrian Griffin       2.0   1.7   1.8
# ...                  ...   ...   ...
# Winston Crite       -0.6  -3.8  -0.1
# Winston Garland     -0.9  -1.2   0.4
# World B. Free       -2.8  -3.3  -0.4
# Xavier Henry        -2.1  -6.0  -0.5
# Xavier McDaniel      0.7   1.5   2.4
# Xavier Munford      -0.1  -3.1  -0.1
# Xavier Silas        -3.7 -10.5  -0.1
# Yakhouba Diawara    -0.8  -3.1  -0.3
# Yao Ming             1.7   1.9   2.4
# Yaroslav Korolev    -1.5  -6.3  -0.1
# Yi Jianlian         -0.7  -4.6  -1.1
# Yinka Dare          -5.5 -39.3   0.0
# Yogi Ferrell        -0.6  -0.7   0.4
# Yuta Tabuse         -2.7  -2.6   0.0
# Yvon Joseph         -3.6  -0.9   0.0
# Zabian Dowdell      -1.0  -4.6  -0.2
# Zach Collins         1.1  -3.2  -0.2
# Zach LaVine         -2.7  -4.5  -1.2
# Zach Randolph       -1.7  -3.4  -0.1
# Zan Tabak           -2.5  -8.2  -0.3
# Zarko Cabarkapa     -1.7  -6.5  -0.7
# Zarko Paspalj       -1.8  -9.2  -0.3
# Zaza Pachulia       -2.5  -6.6  -0.8
# Zeljko Rebraca       0.7  -2.2   0.0
# Zelmo Beaty          NaN   NaN   NaN
# Zendon Hamilton    -11.8 -24.6  -0.1
# Zhou Qi              0.7 -10.0  -0.2
# Zoran Dragic        -4.0  -6.5  -0.1
# Zoran Planinic      -1.4  -4.3  -0.3
# Zydrunas Ilgauskas   1.7   2.0   2.4
#
# [3731 rows x 94 columns]
